# %%
# Course: CS7375 – Artificial Intelligence
# Name: Swetha Pailla
# ID: 000979676
# Project: Term Project
# Due Date: July 24, 2021
# Signature: Swetha...
 


# importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.cluster import KMeans
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from tabulate import tabulate
import matplotlib.pyplot as plt
import warnings

# %%
print("loading labels ....")
labels = pd.read_csv('../input/employeeattritiondataset/labels.csv', header=None)
Y = labels.values
print("loading features ....")
features = pd.read_csv('../input/employeeattritiondataset/features.csv', header=None)
X = features.values
# Out:
# loading labels ....
# loading features ....

# %%
# split the data into training and testing sets
print("Splitting Datasets into Training and Testing Datasets")
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.4, random_state=17)
# Out:
# Splitting Datasets into Training and Testing Datasets

# %% [markdown]
# # K-Nearest Neighbors Classifier

# %%
# KNN classifier
KNN = KNeighborsClassifier(n_neighbors=3, p=1)
# train the classifier
KNN.fit(x_train, y_train.ravel())
# predict the test samples
KNN_pred = KNN.predict(x_test)
# metrics evaluation
KNN_accuracy = (accuracy_score(y_test, KNN_pred))
KNN_Precision=precision_score(y_test, KNN_pred, average='macro') 
KNN_Recall = recall_score(y_test, KNN_pred, average='macro')
KNN_F1 = f1_score(y_test, KNN_pred, average='macro')

print("Accuracy :",KNN_accuracy,"\n%s" % 
      "Precision:",KNN_Precision,"\n%s" % 
      "Recall   :",KNN_Recall, "\n%s" % 
      "F1       :",KNN_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, KNN_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test, KNN_pred, digits=5))
# Out:
# Accuracy : 0.9906270200387848
# Precision: 0.9868643803248456
# Recall   : 0.9789005914038043
# F1       : 0.9828295676811762
#
# Confusion Matrix:
#
# [[1470   59]
#  [  28 7725]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.98131   0.96141   0.97126      1529
#          1.0    0.99242   0.99639   0.99440      7753
#
#     accuracy                        0.99063      9282
#    macro avg    0.98686   0.97890   0.98283      9282
# weighted avg    0.99059   0.99063   0.99059      9282

# %% [markdown]
# # Multi-layer Perceptron classifier

# %%
# create a Multi-layer Perceptron Classifier
MLP =  MLPClassifier(activation='relu',max_iter=20, solver='adam')
# train the classifier
MLP.fit(x_train, y_train.ravel())
# predict the test samples
MLP_pred = MLP.predict(x_test)
# metrics evaluation
MLP_accuracy = (accuracy_score(y_test, MLP_pred))
MLP_Precision=precision_score(y_test, MLP_pred, average='macro') 
MLP_Recall = recall_score(y_test, MLP_pred, average='macro')
MLP_F1 = f1_score(y_test, MLP_pred, average='macro')

print("Accuracy :",MLP_accuracy,"\n%s" % 
      "Precision:",MLP_Precision,"\n%s" % 
      "Recall   :",MLP_Recall, "\n%s" % 
      "F1       :",MLP_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, MLP_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test, MLP_pred, digits=5))

warnings.filterwarnings("ignore")
# Out:
# Accuracy : 0.8740573152337858
# Precision: 0.8079970453912526
# Recall   : 0.6739032727009533
# F1       : 0.7117582665040462
#
# Confusion Matrix:
#
# [[ 574  955]
#  [ 214 7539]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.72843   0.37541   0.49547      1529
#          1.0    0.88757   0.97240   0.92805      7753
#
#     accuracy                        0.87406      9282
#    macro avg    0.80800   0.67390   0.71176      9282
# weighted avg    0.86135   0.87406   0.85679      9282

# %% [markdown]
# # KMeans Cluster

# %%
# KMeans Cluster
KM = KMeans(n_clusters=2, random_state=1)
# train the classifier
KM.fit(x_train, y_train.ravel())
# predict the test samples
KM_pred = KM.predict(x_test)
# metrics evaluation
KM_accuracy = (accuracy_score(y_test, KM_pred))
KM_Precision=precision_score(y_test, KM_pred, average='macro') 
KM_Recall = recall_score(y_test, KM_pred, average='macro')
KM_F1 = f1_score(y_test, KM_pred, average='macro')

print("Accuracy :",KM_accuracy,"\n%s" % 
      "Precision:",KM_Precision,"\n%s" % 
      "Recall   :",KM_Recall, "\n%s" % 
      "F1       :",KM_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, KM_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test, KM_pred, digits=5))
# Out:
# Accuracy : 0.5632406808877397
# Precision: 0.4954370865302039
# Recall   : 0.49204658177003063
# F1       : 0.4606614779411322
#
# Confusion Matrix:
#
# [[ 590  939]
#  [3115 4638]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.15924   0.38587   0.22545      1529
#          1.0    0.83163   0.59822   0.69587      7753
#
#     accuracy                        0.56324      9282
#    macro avg    0.49544   0.49205   0.46066      9282
# weighted avg    0.72087   0.56324   0.61838      9282

# %% [markdown]
# # Naive Bayes classifier

# %%
# create a GaussianNB classifier
NB = GaussianNB()
# train the classifier
NB.fit(x_train, y_train.ravel())
# predict the test samples
NB_pred = NB.predict(x_test)

# metrics evaluation
NB_accuracy = (accuracy_score(y_test, NB_pred))
NB_Precision=precision_score(y_test, NB_pred, average='macro') 
NB_Recall = recall_score(y_test, NB_pred, average='macro')
NB_F1 = f1_score(y_test, NB_pred, average='macro')

print("Accuracy :",NB_accuracy,"\n%s" % 
      "Precision:",NB_Precision,"\n%s" % 
      "Recall   :",NB_Recall, "\n%s" % 
      "F1       :",NB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, NB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test, NB_pred, digits=5))
# Out:
# Accuracy : 0.8265460030165912
# Precision: 0.6634913532590148
# Recall   : 0.6102849952721945
# F1       : 0.6266259513604999
#
# Confusion Matrix:
#
# [[ 440 1089]
#  [ 521 7232]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.45786   0.28777   0.35341      1529
#          1.0    0.86913   0.93280   0.89984      7753
#
#     accuracy                        0.82655      9282
#    macro avg    0.66349   0.61028   0.62663      9282
# weighted avg    0.80138   0.82655   0.80983      9282

# %% [markdown]
# # Decision Tree classifier

# %%
# create a DecisionTree classifier
DT = DecisionTreeClassifier(criterion="gini", random_state=17)
# train the classifier
DT.fit(x_train, y_train.ravel())
# predict the test samples
DT_pred = DT.predict(x_test)

# metrics evaluation
DT_accuracy = (accuracy_score(y_test, DT_pred))
DT_Precision=precision_score(y_test, DT_pred, average='macro') 
DT_Recall = recall_score(y_test, DT_pred, average='macro')
DT_F1 = f1_score(y_test, DT_pred, average='macro')

print("Accuracy :",DT_accuracy,"\n%s" % 
      "Precision:",DT_Precision,"\n%s" % 
      "Recall   :",DT_Recall, "\n%s" % 
      "F1       :",DT_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, DT_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test, DT_pred, digits=5))
# Out:
# Accuracy : 0.9931049342814049
# Precision: 0.9867276562662273
# Recall   : 0.9882594868021721
# F1       : 0.9874916196412027
#
# Confusion Matrix:
#
# [[1500   29]
#  [  35 7718]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.97720   0.98103   0.97911      1529
#          1.0    0.99626   0.99549   0.99587      7753
#
#     accuracy                        0.99310      9282
#    macro avg    0.98673   0.98826   0.98749      9282
# weighted avg    0.99312   0.99310   0.99311      9282

# %% [markdown]
# # Gradient Boosting Classifier

# %%
# create a Gradient Boosting classifier
GB = GradientBoostingClassifier(n_estimators=100, random_state=0)
GB.fit(x_train, y_train.ravel())
# predict the test samples
GB_pred = GB.predict(x_test)

# metrics evaluation
GB_accuracy = (accuracy_score(y_test, GB_pred))
GB_Precision=precision_score(y_test, GB_pred, average='macro') 
GB_Recall = recall_score(y_test, GB_pred, average='macro')
GB_F1 = f1_score(y_test, GB_pred, average='macro')

print("Accuracy :",GB_accuracy,"\n%s" % 
      "Precision:",GB_Precision,"\n%s" % 
      "Recall   :",GB_Recall, "\n%s" % 
      "F1       :",GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test, GB_pred, digits=5))
# Out:
# Accuracy : 0.876642964878259
# Precision: 0.8968236686765352
# Recall   : 0.6352855077428624
# F1       : 0.6773413991936912
#
# Confusion Matrix:
#
# [[ 421 1108]
#  [  37 7716]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.91921   0.27534   0.42375      1529
#          1.0    0.87443   0.99523   0.93093      7753
#
#     accuracy                        0.87664      9282
#    macro avg    0.89682   0.63529   0.67734      9282
# weighted avg    0.88181   0.87664   0.84738      9282

# %% [markdown]
# # Metrics - Individual Classification Models

# %%
# creating a DataFrame
dict = {'Classification Model':['KNN', 'MLP', 'KM', 'NB','DT','GB'],
        'Accuracy':[KNN_accuracy,MLP_accuracy,KM_accuracy,NB_accuracy,DT_accuracy,GB_accuracy],
        'Precision':[KNN_Precision,MLP_Precision,KM_Precision,NB_Precision,DT_Precision,GB_Precision],
        'Recall':[KNN_Recall,MLP_Recall,KM_Recall,NB_Recall,DT_Recall,GB_Recall],
        'F1':[KNN_F1,MLP_F1,KM_F1,NB_F1,DT_F1,GB_F1]
       }
df = pd.DataFrame(dict)
  
# displaying the DataFrame
head = ["Classification Model", "Accuracy", "Precision", "Recall", "F1"]

print(tabulate(df, headers=head, tablefmt="grid"))
# Out:
# +----+------------------------+------------+-------------+----------+----------+
# |    | Classification Model   |   Accuracy |   Precision |   Recall |       F1 |
# +====+========================+============+=============+==========+==========+
# |  0 | KNN                    |   0.990627 |    0.986864 | 0.978901 | 0.98283  |
# +----+------------------------+------------+-------------+----------+----------+
# |  1 | MLP                    |   0.862745 |    0.7936   | 0.628016 | 0.661347 |
# +----+------------------------+------------+-------------+----------+----------+
# |  2 | KM                     |   0.563241 |    0.495437 | 0.492047 | 0.460661 |
# +----+------------------------+------------+-------------+----------+----------+
# |  3 | NB                     |   0.826546 |    0.663491 | 0.610285 | 0.626626 |
# +----+------------------------+------------+-------------+----------+----------+
# |  4 | DT                     |   0.993105 |    0.986728 | 0.988259 | 0.987492 |
# ...

# %% [markdown]
# **Bar Graph**

# %%
Accuracy = [KNN_accuracy,MLP_accuracy,KM_accuracy,NB_accuracy,DT_accuracy,GB_accuracy]
Precision = [KNN_Precision,MLP_Precision,KM_Precision,NB_Precision,DT_Precision,GB_Precision]
Recall = [KNN_Recall,MLP_Recall,KM_Recall,NB_Recall,DT_Recall,GB_Recall]
F1= [KNN_F1,MLP_F1,KM_F1,NB_F1,DT_F1,GB_F1]
index = ['KNN', 'MLP', 'KM', 'NB','DT','GB']
df = pd.DataFrame({'Accuracy': Accuracy,
                   'Precision': Precision,
                   'Recall': Recall, 
                   'F1 Score': F1}, index=index)
ax = df.plot.bar(rot=0)

# %% [markdown]
# # Voting Classifier with Two estimators

# %% [markdown]
# # VC: KNN + MLP

# %%
# create the voting classifier
Vt_KNN_MLP = VotingClassifier(estimators=[('knn', KNN), ('mlp', MLP)], voting = 'hard')
# train the classifier
Vt_KNN_MLP.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_MLP_pred = Vt_KNN_MLP.predict(x_test)

# metrics evaluation
Vth_KNN_MLP_accuracy = (accuracy_score(y_test, Vt_KNN_MLP_pred))
Vth_KNN_MLP_Precision=precision_score(y_test, Vt_KNN_MLP_pred, average='macro') 
Vth_KNN_MLP_Recall = recall_score(y_test,Vt_KNN_MLP_pred, average='macro')
Vth_KNN_MLP_F1 = f1_score(y_test, Vt_KNN_MLP_pred, average='macro')

print("Accuracy :",Vth_KNN_MLP_accuracy,"\n%s" % 
      "Precision:",Vth_KNN_MLP_Precision,"\n%s" % 
      "Recall   :",Vth_KNN_MLP_Recall, "\n%s" % 
      "F1       :",Vth_KNN_MLP_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_MLP_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_MLP_pred, digits=5))
# Out:
# Accuracy : 0.9745744451626804
# Precision: 0.9422286031488343
# Recall   : 0.9695539278156172
# F1       : 0.9552004196274319
#
# Confusion Matrix:
#
# [[1471   58]
#  [ 178 7575]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.89206   0.96207   0.92574      1529
#          1.0    0.99240   0.97704   0.98466      7753
#
#     accuracy                        0.97457      9282
#    macro avg    0.94223   0.96955   0.95520      9282
# weighted avg    0.97587   0.97457   0.97496      9282

# %% [markdown]
# # VC: KNN + NB

# %%
# create the voting classifier
Vt_KNN_NB = VotingClassifier(estimators=[('knn', KNN), ('nb', NB)], voting = 'soft')
# train the classifier
Vt_KNN_NB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_NB_pred = Vt_KNN_NB.predict(x_test)

# metrics evaluation
Vt_KNN_NB_accuracy = (accuracy_score(y_test, Vt_KNN_NB_pred))
Vt_KNN_NB_Precision=precision_score(y_test, Vt_KNN_NB_pred, average='macro') 
Vt_KNN_NB_Recall = recall_score(y_test,Vt_KNN_NB_pred, average='macro')
Vt_KNN_NB_F1 = f1_score(y_test, Vt_KNN_NB_pred, average='macro')

print("Accuracy :",Vt_KNN_NB_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_NB_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_NB_Recall, "\n%s" % 
      "F1       :",Vt_KNN_NB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_NB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_NB_pred, digits=5))
# Out:
# Accuracy : 0.9831932773109243
# Precision: 0.9806923167368077
# Recall   : 0.9576494240040585
# F1       : 0.9687183941697677
#
# Confusion Matrix:
#
# [[1406  123]
#  [  33 7720]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.97707   0.91956   0.94744      1529
#          1.0    0.98432   0.99574   0.99000      7753
#
#     accuracy                        0.98319      9282
#    macro avg    0.98069   0.95765   0.96872      9282
# weighted avg    0.98312   0.98319   0.98299      9282

# %% [markdown]
# # VC: KNN + DT

# %%
# create the voting classifier
Vt_KNN_DT = VotingClassifier(estimators=[('knn', KNN), ('dt', DT)], voting = 'soft')
# train the classifier
Vt_KNN_DT.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_DT_pred = Vt_KNN_DT.predict(x_test)

# metrics evaluation
Vt_KNN_DT_accuracy = (accuracy_score(y_test, Vt_KNN_DT_pred))
Vt_KNN_DT_Precision=precision_score(y_test, Vt_KNN_DT_pred, average='macro') 
Vt_KNN_DT_Recall = recall_score(y_test,Vt_KNN_DT_pred, average='macro')
Vt_KNN_DT_F1 = f1_score(y_test, Vt_KNN_DT_pred, average='macro')

print("Accuracy :",Vt_KNN_DT_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_DT_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_DT_Recall, "\n%s" % 
      "F1       :",Vt_KNN_DT_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_DT_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_DT_pred, digits=5))
# Out:
# Accuracy : 0.9937513466925232
# Precision: 0.9845074061337293
# Recall   : 0.9931092730027837
# F1       : 0.988746603638037
#
# Confusion Matrix:
#
# [[1517   12]
#  [  46 7707]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.97057   0.99215   0.98124      1529
#          1.0    0.99845   0.99407   0.99625      7753
#
#     accuracy                        0.99375      9282
#    macro avg    0.98451   0.99311   0.98875      9282
# weighted avg    0.99385   0.99375   0.99378      9282

# %% [markdown]
# # VC: KNN + GB

# %%
# create the voting classifier
Vt_KNN_GB = VotingClassifier(estimators=[('knn', KNN), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_KNN_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_GB_pred = Vt_KNN_GB.predict(x_test)

# metrics evaluation
Vt_KNN_GB_accuracy = (accuracy_score(y_test, Vt_KNN_GB_pred))
Vt_KNN_GB_Precision=precision_score(y_test, Vt_KNN_GB_pred, average='macro') 
Vt_KNN_GB_Recall = recall_score(y_test,Vt_KNN_GB_pred, average='macro')
Vt_KNN_GB_F1 = f1_score(y_test, Vt_KNN_GB_pred, average='macro')

print("Accuracy :",Vt_KNN_GB_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_GB_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_GB_Recall, "\n%s" % 
      "F1       :",Vt_KNN_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_GB_pred, digits=5))
# Out:
# Accuracy : 0.9848093083387202
# Precision: 0.9869837791481898
# Recall   : 0.9575667116600448
# F1       : 0.9715473872697167
#
# Confusion Matrix:
#
# [[1402  127]
#  [  14 7739]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.99011   0.91694   0.95212      1529
#          1.0    0.98385   0.99819   0.99097      7753
#
#     accuracy                        0.98481      9282
#    macro avg    0.98698   0.95757   0.97155      9282
# weighted avg    0.98489   0.98481   0.98457      9282

# %% [markdown]
# # VC: MLP + NB

# %%
# create the voting classifier
Vt_MLP_NB = VotingClassifier(estimators=[('mlp', MLP), ('nb', NB)], voting = 'soft')
# train the classifier
Vt_MLP_NB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_MLP_NB_pred = Vt_MLP_NB.predict(x_test)

# metrics evaluation
Vt_MLP_NB_accuracy = (accuracy_score(y_test, Vt_MLP_NB_pred))
Vt_MLP_NB_Precision=precision_score(y_test, Vt_MLP_NB_pred, average='macro') 
Vt_MLP_NB_Recall = recall_score(y_test,Vt_MLP_NB_pred, average='macro')
Vt_MLP_NB_F1 = f1_score(y_test, Vt_MLP_NB_pred, average='macro')

print("Accuracy :",Vt_MLP_NB_accuracy,"\n%s" % 
      "Precision:",Vt_MLP_NB_Precision,"\n%s" % 
      "Recall   :",Vt_MLP_NB_Recall, "\n%s" % 
      "F1       :",Vt_MLP_NB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_MLP_NB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_MLP_NB_pred, digits=5))
# Out:
# Accuracy : 0.8560655031243266
# Precision: 0.7653084904646444
# Recall   : 0.6164046964414795
# F1       : 0.6454477334733768
#
# Confusion Matrix:
#
# [[ 396 1133]
#  [ 203 7550]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.66110   0.25899   0.37218      1529
#          1.0    0.86952   0.97382   0.91872      7753
#
#     accuracy                        0.85607      9282
#    macro avg    0.76531   0.61640   0.64545      9282
# weighted avg    0.83518   0.85607   0.82869      9282

# %% [markdown]
# # VC: MLP + DT

# %%
# create the voting classifier
Vt_MLP_DT = VotingClassifier(estimators=[('mlp', MLP), ('dt', DT)], voting = 'soft')
# train the classifier
Vt_MLP_DT.fit(x_train, y_train.ravel())
# predict the test samples
Vt_MLP_DT_pred = Vt_MLP_DT.predict(x_test)

# metrics evaluation
Vt_MLP_DT_accuracy = (accuracy_score(y_test, Vt_MLP_DT_pred))
Vt_MLP_DT_Precision=precision_score(y_test, Vt_MLP_DT_pred, average='macro') 
Vt_MLP_DT_Recall = recall_score(y_test,Vt_MLP_DT_pred, average='macro')
Vt_MLP_DT_F1 = f1_score(y_test, Vt_MLP_DT_pred, average='macro')

print("Accuracy :",Vt_MLP_DT_accuracy,"\n%s" % 
      "Precision:",Vt_MLP_DT_Precision,"\n%s" % 
      "Recall   :",Vt_MLP_DT_Recall, "\n%s" % 
      "F1       :",Vt_MLP_DT_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_MLP_DT_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_MLP_DT_pred, digits=5))
# Out:
# Accuracy : 0.9931049342814049
# Precision: 0.9867276562662273
# Recall   : 0.9882594868021721
# F1       : 0.9874916196412027
#
# Confusion Matrix:
#
# [[1500   29]
#  [  35 7718]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.97720   0.98103   0.97911      1529
#          1.0    0.99626   0.99549   0.99587      7753
#
#     accuracy                        0.99310      9282
#    macro avg    0.98673   0.98826   0.98749      9282
# weighted avg    0.99312   0.99310   0.99311      9282

# %% [markdown]
# # VC: MLP + GB

# %%
# create the voting classifier
Vt_MLP_GB = VotingClassifier(estimators=[('mlp', MLP), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_MLP_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_MLP_GB_pred = Vt_MLP_GB.predict(x_test)

# metrics evaluation
Vt_MLP_GB_accuracy = (accuracy_score(y_test, Vt_MLP_GB_pred))
Vt_MLP_GB_Precision=precision_score(y_test, Vt_MLP_GB_pred, average='macro') 
Vt_MLP_GB_Recall = recall_score(y_test,Vt_MLP_GB_pred, average='macro')
Vt_MLP_GB_F1 = f1_score(y_test, Vt_MLP_GB_pred, average='macro')

print("Accuracy :",Vt_MLP_GB_accuracy,"\n%s" % 
      "Precision:",Vt_MLP_GB_Precision,"\n%s" % 
      "Recall   :",Vt_MLP_GB_Recall, "\n%s" % 
      "F1       :",Vt_MLP_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_MLP_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_MLP_GB_pred, digits=5))
# Out:
# Accuracy : 0.8756733462615816
# Precision: 0.8702160905691134
# Recall   : 0.6410055661484906
# F1       : 0.6827830110451425
#
# Confusion Matrix:
#
# [[ 445 1084]
#  [  70 7683]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.86408   0.29104   0.43542      1529
#          1.0    0.87635   0.99097   0.93015      7753
#
#     accuracy                        0.87567      9282
#    macro avg    0.87022   0.64101   0.68278      9282
# weighted avg    0.87433   0.87567   0.84865      9282

# %% [markdown]
# # VC: NB + DT

# %%
# create the voting classifier
Vt_NB_DT = VotingClassifier(estimators=[('nb', NB), ('dt', DT)], voting = 'soft')
# train the classifier
Vt_NB_DT.fit(x_train, y_train.ravel())
# predict the test samples
Vt_NB_DT_pred = Vt_NB_DT.predict(x_test)

# metrics evaluation
Vt_NB_DT_accuracy = (accuracy_score(y_test, Vt_NB_DT_pred))
Vt_NB_DT_Precision=precision_score(y_test, Vt_NB_DT_pred, average='macro') 
Vt_NB_DT_Recall = recall_score(y_test,Vt_NB_DT_pred, average='macro')
Vt_NB_DT_F1 = f1_score(y_test, Vt_NB_DT_pred, average='macro')

print("Accuracy :",Vt_NB_DT_accuracy,"\n%s" % 
      "Precision:",Vt_NB_DT_Precision,"\n%s" % 
      "Recall   :",Vt_NB_DT_Recall, "\n%s" % 
      "F1       :",Vt_NB_DT_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_NB_DT_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_NB_DT_pred, digits=5))
# Out:
# Accuracy : 0.9931049342814049
# Precision: 0.9867276562662273
# Recall   : 0.9882594868021721
# F1       : 0.9874916196412027
#
# Confusion Matrix:
#
# [[1500   29]
#  [  35 7718]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.97720   0.98103   0.97911      1529
#          1.0    0.99626   0.99549   0.99587      7753
#
#     accuracy                        0.99310      9282
#    macro avg    0.98673   0.98826   0.98749      9282
# weighted avg    0.99312   0.99310   0.99311      9282

# %% [markdown]
# # VC: NB + GB

# %%
# create the voting classifier
Vt_NB_GB = VotingClassifier(estimators=[('nb', NB), ('gb', GB)], voting = 'hard')
# train the classifier
Vt_NB_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_NB_GB_pred = Vt_NB_GB.predict(x_test)

# metrics evaluation
Vth_NB_GB_accuracy = (accuracy_score(y_test, Vt_NB_GB_pred))
Vth_NB_GB_Precision=precision_score(y_test, Vt_NB_GB_pred, average='macro') 
Vth_NB_GB_Recall = recall_score(y_test,Vt_NB_GB_pred, average='macro')
Vth_NB_GB_F1 = f1_score(y_test, Vt_NB_GB_pred, average='macro')

print("Accuracy :",Vth_NB_GB_accuracy,"\n%s" % 
      "Precision:",Vth_NB_GB_Precision,"\n%s" % 
      "Recall   :",Vth_NB_GB_Recall, "\n%s" % 
      "F1       :",Vth_NB_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_NB_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_NB_GB_pred, digits=5))
# Out:
# Accuracy : 0.8420599008834303
# Precision: 0.7065987376518659
# Recall   : 0.6589497160406356
# F1       : 0.6769295815658424
#
# Confusion Matrix:
#
# [[ 590  939]
#  [ 527 7226]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.52820   0.38587   0.44596      1529
#          1.0    0.88500   0.93203   0.90790      7753
#
#     accuracy                        0.84206      9282
#    macro avg    0.70660   0.65895   0.67693      9282
# weighted avg    0.82622   0.84206   0.83181      9282

# %% [markdown]
# # VC: DT + GB

# %%
# create the voting classifier
Vt_DT_GB = VotingClassifier(estimators=[('dt', DT), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_DT_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_DT_GB_pred = Vt_DT_GB.predict(x_test)

# metrics evaluation
Vt_DT_GB_accuracy = (accuracy_score(y_test, Vt_DT_GB_pred))
Vt_DT_GB_Precision=precision_score(y_test, Vt_DT_GB_pred, average='macro') 
Vt_DT_GB_Recall = recall_score(y_test,Vt_DT_GB_pred, average='macro')
Vt_DT_GB_F1 = f1_score(y_test, Vt_DT_GB_pred, average='macro')

print("Accuracy :",Vt_DT_GB_accuracy,"\n%s" % 
      "Precision:",Vt_DT_GB_Precision,"\n%s" % 
      "Recall   :",Vt_DT_GB_Recall, "\n%s" % 
      "F1       :",Vt_DT_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_DT_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_DT_GB_pred, digits=5))
# Out:
# Accuracy : 0.9931049342814049
# Precision: 0.9867276562662273
# Recall   : 0.9882594868021721
# F1       : 0.9874916196412027
#
# Confusion Matrix:
#
# [[1500   29]
#  [  35 7718]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.97720   0.98103   0.97911      1529
#          1.0    0.99626   0.99549   0.99587      7753
#
#     accuracy                        0.99310      9282
#    macro avg    0.98673   0.98826   0.98749      9282
# weighted avg    0.99312   0.99310   0.99311      9282

# %% [markdown]
# # Metrics - VC: Two Estimators

# %%
# creating a DataFrame
dict = {'Estimators':['KNN+MLP', 'KNN+NB','KNN+DT','KNN+GB','MLP+NB','MLP+DT', 'MLP+GB','NB+DT', 'NB+GB','DT+GB'],
        'Config': ['hard', 'soft', 'soft', 'soft', 'soft', 'soft', 'soft', 'soft', 'hard', 'soft'],
        'Accuracy':[Vth_KNN_MLP_accuracy, Vt_KNN_NB_accuracy, Vt_KNN_DT_accuracy,  Vt_KNN_GB_accuracy, 
                    Vt_MLP_NB_accuracy,   Vt_MLP_DT_accuracy, Vt_MLP_GB_accuracy,  Vt_NB_DT_accuracy, 
                    Vth_NB_GB_accuracy,   Vt_DT_GB_accuracy],                    
        'Precision':[Vth_KNN_MLP_Precision, Vt_KNN_NB_Precision, Vt_KNN_DT_Precision,  Vt_KNN_GB_Precision, 
                    Vt_MLP_NB_Precision,   Vt_MLP_DT_Precision, Vt_MLP_GB_Precision,  Vt_NB_DT_Precision, 
                    Vth_NB_GB_Precision,   Vt_DT_GB_Precision],
        'Recall':[Vth_KNN_MLP_Recall, Vt_KNN_NB_Recall, Vt_KNN_DT_Recall,  Vt_KNN_GB_Recall, 
                    Vt_MLP_NB_Recall,   Vt_MLP_DT_Recall, Vt_MLP_GB_Recall,  Vt_NB_DT_Recall, 
                    Vth_NB_GB_Recall,   Vt_DT_GB_Recall],
        'F1':[Vth_KNN_MLP_F1, Vt_KNN_NB_F1, Vt_KNN_DT_F1,  Vt_KNN_GB_F1, 
                    Vt_MLP_NB_F1,   Vt_MLP_DT_F1, Vt_MLP_GB_F1,  Vt_NB_DT_F1, 
                    Vth_NB_GB_F1,   Vt_DT_GB_F1]
       }
df = pd.DataFrame(dict)
  
# displaying the DataFrame
# print(tabulate(df, headers = 'keys', tablefmt = 'psql'))

head = ["Estimators", "Config", "Accuracy", "Precision", "Recall", "F1"]

print(tabulate(df, headers=head, tablefmt="grid"))
# Out:
# +----+--------------+----------+------------+-------------+----------+----------+
# |    | Estimators   | Config   |   Accuracy |   Precision |   Recall |       F1 |
# +====+==============+==========+============+=============+==========+==========+
# |  0 | KNN+MLP      | hard     |   0.974574 |    0.942229 | 0.969554 | 0.9552   |
# +----+--------------+----------+------------+-------------+----------+----------+
# |  1 | KNN+NB       | soft     |   0.983193 |    0.980692 | 0.957649 | 0.968718 |
# +----+--------------+----------+------------+-------------+----------+----------+
# |  2 | KNN+DT       | soft     |   0.998651 |    0.984507 | 0.993109 | 0.988747 |
# +----+--------------+----------+------------+-------------+----------+----------+
# |  3 | KNN+GB       | soft     |   0.984809 |    0.986984 | 0.957567 | 0.971547 |
# +----+--------------+----------+------------+-------------+----------+----------+
# ...

# %%
Accuracy = [Vth_KNN_MLP_accuracy, Vt_KNN_NB_accuracy, Vt_KNN_DT_accuracy,  Vt_KNN_GB_accuracy, 
                    Vt_MLP_NB_accuracy,   Vt_MLP_DT_accuracy, Vt_MLP_GB_accuracy,  Vt_NB_DT_accuracy, 
                    Vth_NB_GB_accuracy,   Vt_DT_GB_accuracy]
Precision = [Vth_KNN_MLP_Precision, Vt_KNN_NB_Precision, Vt_KNN_DT_Precision,  Vt_KNN_GB_Precision, 
                    Vt_MLP_NB_Precision,   Vt_MLP_DT_Precision, Vt_MLP_GB_Precision,  Vt_NB_DT_Precision, 
                    Vth_NB_GB_Precision,   Vt_DT_GB_Precision]
Recall = [Vth_KNN_MLP_Recall, Vt_KNN_NB_Recall, Vt_KNN_DT_Recall,  Vt_KNN_GB_Recall, 
                    Vt_MLP_NB_Recall,   Vt_MLP_DT_Recall, Vt_MLP_GB_Recall,  Vt_NB_DT_Recall, 
                    Vth_NB_GB_Recall,   Vt_DT_GB_Recall]
F1= [Vth_KNN_MLP_F1, Vt_KNN_NB_F1, Vt_KNN_DT_F1,  Vt_KNN_GB_F1, 
                    Vt_MLP_NB_F1,   Vt_MLP_DT_F1, Vt_MLP_GB_F1,  Vt_NB_DT_F1, 
                    Vth_NB_GB_F1,   Vt_DT_GB_F1]
index = ['KNN+MLP', 'KNN+NB','KNN+DT','KNN+GB','MLP+NB','MLP+DT', 'MLP+GB','NB+DT', 'NB+GB','DT+GB']
                       
df = pd.DataFrame({'Accuracy': Accuracy,
                   'Precision': Precision,
                   'Recall': Recall, 
                   'F1 Score': F1}, index=index)
ax = df.plot.bar(rot=1,figsize=(10, 8))

# %% [markdown]
# # Voting Classifier with Three estimators

# %% [markdown]
# # VC: KNN + MLP + NB

# %%
# create the voting classifier
Vt_KNN_MLP_NB = VotingClassifier(estimators=[('knn', KNN), ('mlp', MLP), ('nb', NB)], voting = 'soft')
# train the classifier
Vt_KNN_MLP_NB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_MLP_NB_pred = Vt_KNN_MLP_NB.predict(x_test)

# metrics evaluation
Vt_KNN_MLP_NB_accuracy = (accuracy_score(y_test, Vt_KNN_MLP_NB_pred))
Vt_KNN_MLP_NB_Precision=precision_score(y_test, Vt_KNN_MLP_NB_pred, average='macro') 
Vt_KNN_MLP_NB_Recall = recall_score(y_test,Vt_KNN_MLP_NB_pred, average='macro')
Vt_KNN_MLP_NB_F1 = f1_score(y_test, Vt_KNN_MLP_NB_pred, average='macro')

print("Accuracy :",Vt_KNN_MLP_NB_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_MLP_NB_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_MLP_NB_Recall, "\n%s" % 
      "F1       :",Vt_KNN_MLP_NB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_MLP_NB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_MLP_NB_pred, digits=5))
# Out:
# Accuracy : 0.9269553975436329
# Precision: 0.9452928811333301
# Recall   : 0.7858995403960592
# F1       : 0.8399296475448623
#
# Confusion Matrix:
#
# [[ 880  649]
#  [  29 7724]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.96810   0.57554   0.72190      1529
#          1.0    0.92249   0.99626   0.95796      7753
#
#     accuracy                        0.92696      9282
#    macro avg    0.94529   0.78590   0.83993      9282
# weighted avg    0.93000   0.92696   0.91907      9282

# %% [markdown]
# # VC: KNN + MLP + DT

# %%
# create the voting classifier
Vt_KNN_MLP_DT = VotingClassifier(estimators=[('knn', KNN), ('mlp', MLP), ('dt', DT)], voting = 'soft')
# train the classifier
Vt_KNN_MLP_DT.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_MLP_DT_pred = Vt_KNN_MLP_DT.predict(x_test)

# metrics evaluation
Vt_KNN_MLP_DT_accuracy = (accuracy_score(y_test, Vt_KNN_MLP_DT_pred))
Vt_KNN_MLP_DT_Precision=precision_score(y_test, Vt_KNN_MLP_DT_pred, average='macro') 
Vt_KNN_MLP_DT_Recall = recall_score(y_test,Vt_KNN_MLP_DT_pred, average='macro')
Vt_KNN_MLP_DT_F1 = f1_score(y_test, Vt_KNN_MLP_DT_pred, average='macro')

print("Accuracy :",Vt_KNN_MLP_DT_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_MLP_DT_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_MLP_DT_Recall, "\n%s" % 
      "F1       :",Vt_KNN_MLP_DT_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_MLP_DT_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_MLP_DT_pred, digits=5))
# Out:
# Accuracy : 0.9919198448610214
# Precision: 0.9903021340076898
# Recall   : 0.9801995252876647
# F1       : 0.9851663171949158
#
# Confusion Matrix:
#
# [[1472   57]
#  [  18 7735]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.98792   0.96272   0.97516      1529
#          1.0    0.99268   0.99768   0.99518      7753
#
#     accuracy                        0.99192      9282
#    macro avg    0.99030   0.98020   0.98517      9282
# weighted avg    0.99190   0.99192   0.99188      9282

# %% [markdown]
# # VC: KNN + MLP + GB

# %%
# create the voting classifier
Vt_KNN_MLP_GB = VotingClassifier(estimators=[('knn', KNN), ('mlp', MLP), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_KNN_MLP_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_MLP_GB_pred = Vt_KNN_MLP_GB.predict(x_test)

# metrics evaluation
Vt_KNN_MLP_GB_accuracy = (accuracy_score(y_test, Vt_KNN_MLP_GB_pred))
Vt_KNN_MLP_GB_Precision=precision_score(y_test, Vt_KNN_MLP_GB_pred, average='macro') 
Vt_KNN_MLP_GB_Recall = recall_score(y_test,Vt_KNN_MLP_GB_pred, average='macro')
Vt_KNN_MLP_GB_F1 = f1_score(y_test, Vt_KNN_MLP_GB_pred, average='macro')

print("Accuracy :",Vt_KNN_MLP_GB_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_MLP_GB_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_MLP_GB_Recall, "\n%s" % 
      "F1       :",Vt_KNN_MLP_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_MLP_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_MLP_GB_pred, digits=5))
# Out:
# Accuracy : 0.9398836457659987
# Precision: 0.9575855290749883
# Recall   : 0.8227781950184139
# F1       : 0.872746097389349
#
# Confusion Matrix:
#
# [[ 991  538]
#  [  20 7733]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.98022   0.64814   0.78031      1529
#          1.0    0.93495   0.99742   0.96518      7753
#
#     accuracy                        0.93988      9282
#    macro avg    0.95759   0.82278   0.87275      9282
# weighted avg    0.94241   0.93988   0.93473      9282

# %% [markdown]
# # VC: KNN + NB + DT

# %%
# create the voting classifier
Vt_KNN_NB_DT = VotingClassifier(estimators=[('knn', KNN), ('nb', NB), ('dt', DT)], voting = 'soft')
# train the classifier
Vt_KNN_NB_DT.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_NB_DT_pred = Vt_KNN_NB_DT.predict(x_test)

# metrics evaluation
Vt_KNN_NB_DT_accuracy = (accuracy_score(y_test, Vt_KNN_NB_DT_pred))
Vt_KNN_NB_DT_Precision=precision_score(y_test, Vt_KNN_NB_DT_pred, average='macro') 
Vt_KNN_NB_DT_Recall = recall_score(y_test,Vt_KNN_NB_DT_pred, average='macro')
Vt_KNN_NB_DT_F1 = f1_score(y_test, Vt_KNN_NB_DT_pred, average='macro')

print("Accuracy :",Vt_KNN_NB_DT_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_NB_DT_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_NB_DT_Recall, "\n%s" % 
      "F1       :",Vt_KNN_NB_DT_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_NB_DT_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_NB_DT_pred, digits=5))
# Out:
# Accuracy : 0.9924585218702866
# Precision: 0.9906410349467619
# Recall   : 0.9818345808795549
# F1       : 0.9861736736736737
#
# Confusion Matrix:
#
# [[1477   52]
#  [  18 7735]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.98796   0.96599   0.97685      1529
#          1.0    0.99332   0.99768   0.99550      7753
#
#     accuracy                        0.99246      9282
#    macro avg    0.99064   0.98183   0.98617      9282
# weighted avg    0.99244   0.99246   0.99242      9282

# %% [markdown]
# # VC: KNN + NB + GB

# %%
# create the voting classifier
Vt_KNN_NB_GB = VotingClassifier(estimators=[('knn', KNN), ('nb', NB), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_KNN_NB_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_NB_GB_pred = Vt_KNN_NB_GB.predict(x_test)

# metrics evaluation
Vt_KNN_NB_GB_accuracy = (accuracy_score(y_test, Vt_KNN_NB_GB_pred))
Vt_KNN_NB_GB_Precision=precision_score(y_test, Vt_KNN_NB_GB_pred, average='macro') 
Vt_KNN_NB_GB_Recall = recall_score(y_test,Vt_KNN_NB_GB_pred, average='macro')
Vt_KNN_NB_GB_F1 = f1_score(y_test, Vt_KNN_NB_GB_pred, average='macro')

print("Accuracy :",Vt_KNN_NB_GB_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_NB_GB_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_NB_GB_Recall, "\n%s" % 
      "F1       :",Vt_KNN_NB_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_NB_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_NB_GB_pred, digits=5))
# Out:
# Accuracy : 0.9285714285714286
# Precision: 0.945471222746898
# Recall   : 0.7913297470790648
# F1       : 0.8444982512779122
#
# Confusion Matrix:
#
# [[ 897  632]
#  [  31 7722]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.96659   0.58666   0.73016      1529
#          1.0    0.92435   0.99600   0.95884      7753
#
#     accuracy                        0.92857      9282
#    macro avg    0.94547   0.79133   0.84450      9282
# weighted avg    0.93131   0.92857   0.92117      9282

# %% [markdown]
# # VC: KNN + DT + GB

# %%
# create the voting classifier
Vt_KNN_DT_GB = VotingClassifier(estimators=[('knn', KNN), ('dt', DT), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_KNN_DT_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_DT_GB_pred = Vt_KNN_DT_GB.predict(x_test)

# metrics evaluation
Vt_KNN_DT_GB_accuracy = (accuracy_score(y_test, Vt_KNN_DT_GB_pred))
Vt_KNN_DT_GB_Precision=precision_score(y_test, Vt_KNN_DT_GB_pred, average='macro') 
Vt_KNN_DT_GB_Recall = recall_score(y_test,Vt_KNN_DT_GB_pred, average='macro')
Vt_KNN_DT_GB_F1 = f1_score(y_test, Vt_KNN_DT_GB_pred, average='macro')

print("Accuracy :",Vt_KNN_DT_GB_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_DT_GB_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_DT_GB_Recall, "\n%s" % 
      "F1       :",Vt_KNN_DT_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_DT_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_DT_GB_pred, digits=5))
# Out:
# Accuracy : 0.9925662572721397
# Precision: 0.9939286658687302
# Recall   : 0.9790113525539219
# F1       : 0.9862870358084712
#
# Confusion Matrix:
#
# [[1466   63]
#  [   6 7747]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.99592   0.95880   0.97701      1529
#          1.0    0.99193   0.99923   0.99557      7753
#
#     accuracy                        0.99257      9282
#    macro avg    0.99393   0.97901   0.98629      9282
# weighted avg    0.99259   0.99257   0.99251      9282

# %% [markdown]
# # VC: MLP + NB + DT

# %%
# create the voting classifier
Vt_MLP_NB_DT = VotingClassifier(estimators=[('mlp', MLP), ('nb', NB), ('dt', DT)], voting = 'soft')
# train the classifier
Vt_MLP_NB_DT.fit(x_train, y_train.ravel())
# predict the test samples
Vt_MLP_NB_DT_pred = Vt_MLP_NB_DT.predict(x_test)

# metrics evaluation
Vt_MLP_NB_DT_accuracy = (accuracy_score(y_test, Vt_MLP_NB_DT_pred))
Vt_MLP_NB_DT_Precision=precision_score(y_test, Vt_MLP_NB_DT_pred, average='macro') 
Vt_MLP_NB_DT_Recall = recall_score(y_test,Vt_MLP_NB_DT_pred, average='macro')
Vt_MLP_NB_DT_F1 = f1_score(y_test, Vt_MLP_NB_DT_pred, average='macro')

print("Accuracy :",Vt_MLP_NB_DT_accuracy,"\n%s" % 
      "Precision:",Vt_MLP_NB_DT_Precision,"\n%s" % 
      "Recall   :",Vt_MLP_NB_DT_Recall, "\n%s" % 
      "F1       :",Vt_MLP_NB_DT_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_MLP_NB_DT_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_MLP_NB_DT_pred, digits=5))
# Out:
# Accuracy : 0.9253393665158371
# Precision: 0.9461107998326624
# Recall   : 0.7799442938057186
# F1       : 0.8350653021993555
#
# Confusion Matrix:
#
# [[ 861  668]
#  [  25 7728]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.97178   0.56311   0.71304      1529
#          1.0    0.92044   0.99678   0.95709      7753
#
#     accuracy                        0.92534      9282
#    macro avg    0.94611   0.77994   0.83507      9282
# weighted avg    0.92890   0.92534   0.91689      9282

# %% [markdown]
# # VC: MLP + NB + GB

# %%
# create the voting classifier
Vt_MLP_NB_GB = VotingClassifier(estimators=[('mlp', MLP), ('nb', NB), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_MLP_NB_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_MLP_NB_GB_pred = Vt_MLP_NB_GB.predict(x_test)

# metrics evaluation
Vt_MLP_NB_GB_accuracy = (accuracy_score(y_test, Vt_MLP_NB_GB_pred))
Vt_MLP_NB_GB_Precision=precision_score(y_test, Vt_MLP_NB_GB_pred, average='macro') 
Vt_MLP_NB_GB_Recall = recall_score(y_test,Vt_MLP_NB_GB_pred, average='macro')
Vt_MLP_NB_GB_F1 = f1_score(y_test, Vt_MLP_NB_GB_pred, average='macro')

print("Accuracy :",Vt_MLP_NB_GB_accuracy,"\n%s" % 
      "Precision:",Vt_MLP_NB_GB_Precision,"\n%s" % 
      "Recall   :",Vt_MLP_NB_GB_Recall, "\n%s" % 
      "F1       :",Vt_MLP_NB_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_MLP_NB_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_MLP_NB_GB_pred, digits=5))
# Out:
# Accuracy : 0.8652230122818358
# Precision: 0.8182353233423225
# Recall   : 0.6231990452102045
# F1       : 0.6574400812010874
#
# Confusion Matrix:
#
# [[ 401 1128]
#  [ 123 7630]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.76527   0.26226   0.39065      1529
#          1.0    0.87120   0.98414   0.92423      7753
#
#     accuracy                        0.86522      9282
#    macro avg    0.81824   0.62320   0.65744      9282
# weighted avg    0.85375   0.86522   0.83634      9282

# %% [markdown]
# # VC: MLP + DT + GB

# %%
# create the voting classifier
Vt_MLP_DT_GB= VotingClassifier(estimators=[('mlp', MLP), ('dt', DT), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_MLP_DT_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_MLP_DT_GB_pred = Vt_MLP_DT_GB.predict(x_test)

# metrics evaluation
Vt_MLP_DT_GB_accuracy = (accuracy_score(y_test, Vt_MLP_DT_GB_pred))
Vt_MLP_DT_GB_Precision=precision_score(y_test, Vt_MLP_DT_GB_pred, average='macro') 
Vt_MLP_DT_GB_Recall = recall_score(y_test,Vt_MLP_DT_GB_pred, average='macro')
Vt_MLP_DT_GB_F1 = f1_score(y_test, Vt_MLP_DT_GB_pred, average='macro')

print("Accuracy :",Vt_MLP_DT_GB_accuracy,"\n%s" % 
      "Precision:",Vt_MLP_DT_GB_Precision,"\n%s" % 
      "Recall   :",Vt_MLP_DT_GB_Recall, "\n%s" % 
      "F1       :",Vt_MLP_DT_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_MLP_DT_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_MLP_DT_GB_pred, digits=5))
# Out:
# Accuracy : 0.9407455289808231
# Precision: 0.9610930487107774
# Recall   : 0.823556644289765
# F1       : 0.8743205936383094
#
# Confusion Matrix:
#
# [[ 992  537]
#  [  13 7740]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.98706   0.64879   0.78295      1529
#          1.0    0.93512   0.99832   0.96569      7753
#
#     accuracy                        0.94075      9282
#    macro avg    0.96109   0.82356   0.87432      9282
# weighted avg    0.94368   0.94075   0.93559      9282

# %% [markdown]
# # VC: NB + DT + GB

# %%
# create the voting classifier
Vt_NB_DT_GB= VotingClassifier(estimators=[('nb', NB), ('dt', DT), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_NB_DT_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_NB_DT_GB_pred = Vt_NB_DT_GB.predict(x_test)

# metrics evaluation
Vt_NB_DT_GB_accuracy = (accuracy_score(y_test, Vt_NB_DT_GB_pred))
Vt_NB_DT_GB_Precision=precision_score(y_test, Vt_NB_DT_GB_pred, average='macro') 
Vt_NB_DT_GB_Recall = recall_score(y_test,Vt_NB_DT_GB_pred, average='macro')
Vt_NB_DT_GB_F1 = f1_score(y_test, Vt_NB_DT_GB_pred, average='macro')

print("Accuracy :",Vt_NB_DT_GB_accuracy,"\n%s" % 
      "Precision:",Vt_NB_DT_GB_Precision,"\n%s" % 
      "Recall   :",Vt_NB_DT_GB_Recall, "\n%s" % 
      "F1       :",Vt_NB_DT_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_NB_DT_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_NB_DT_GB_pred, digits=5))
# Out:
# Accuracy : 0.9310493428140487
# Precision: 0.9493787713178476
# Recall   : 0.7975384030334214
# F1       : 0.8505621578489531
#
# Confusion Matrix:
#
# [[ 915  614]
#  [  26 7727]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.97237   0.59843   0.74089      1529
#          1.0    0.92639   0.99665   0.96023      7753
#
#     accuracy                        0.93105      9282
#    macro avg    0.94938   0.79754   0.85056      9282
# weighted avg    0.93396   0.93105   0.92410      9282

# %% [markdown]
# # Metrics - VC : Three Estimators

# %%
# creating a DataFrame
dict = {'Estimators':['KNN+MLP+NB','KNN+MLP+DT','KNN+MLP+GB','KNN+NB+DT','KNN+NB+GB','KNN+DT+GB',
                      'MLP+NB+DT','MLP+NB+GB','MLP+DT+GB','NB+DT+GB'],
        'Config': ['soft', 'soft', 'soft', 'soft', 'soft', 'soft', 'soft', 'soft', 'soft', 'soft'],
        'Accuracy':[Vt_KNN_MLP_NB_accuracy, Vt_KNN_MLP_DT_accuracy, Vt_KNN_MLP_GB_accuracy, Vt_KNN_NB_DT_accuracy,
                    Vt_KNN_NB_GB_accuracy, Vt_KNN_DT_GB_accuracy, Vt_MLP_NB_DT_accuracy, Vt_MLP_NB_GB_accuracy,
                    Vt_MLP_DT_GB_accuracy,Vt_NB_DT_GB_accuracy],
                                       
        'Precision':[Vt_KNN_MLP_NB_Precision, Vt_KNN_MLP_DT_Precision, Vt_KNN_MLP_GB_Precision, Vt_KNN_NB_DT_Precision,
                    Vt_KNN_NB_GB_Precision, Vt_KNN_DT_GB_Precision, Vt_MLP_NB_DT_Precision, Vt_MLP_NB_GB_Precision,
                    Vt_MLP_DT_GB_Precision,Vt_NB_DT_GB_Precision],
        
        'Recall':[Vt_KNN_MLP_NB_Recall, Vt_KNN_MLP_DT_Recall, Vt_KNN_MLP_GB_Recall, Vt_KNN_NB_DT_Recall,
                    Vt_KNN_NB_GB_Recall, Vt_KNN_DT_GB_Recall, Vt_MLP_NB_DT_Recall, Vt_MLP_NB_GB_Recall,
                    Vt_MLP_DT_GB_Recall,Vt_NB_DT_GB_Recall],
        
        'F1':[Vt_KNN_MLP_NB_F1, Vt_KNN_MLP_DT_F1, Vt_KNN_MLP_GB_F1, Vt_KNN_NB_DT_F1,
                    Vt_KNN_NB_GB_F1, Vt_KNN_DT_GB_F1, Vt_MLP_NB_DT_F1, Vt_MLP_NB_GB_F1,
                    Vt_MLP_DT_GB_F1,Vt_NB_DT_GB_F1]
       }
df = pd.DataFrame(dict)
  
# displaying the DataFrame
# print(tabulate(df, headers = 'keys', tablefmt = 'psql'))

head = ["3 Estimators", "Config", "Accuracy", "Precision", "Recall", "F1"]

print(tabulate(df, headers=head, tablefmt="grid"))
# Out:
# +----+----------------+----------+------------+-------------+----------+----------+
# |    | 3 Estimators   | Config   |   Accuracy |   Precision |   Recall |       F1 |
# +====+================+==========+============+=============+==========+==========+
# |  0 | KNN+MLP+NB     | soft     |   0.926955 |    0.945293 | 0.7859   | 0.83993  |
# +----+----------------+----------+------------+-------------+----------+----------+
# |  1 | KNN+MLP+DT     | soft     |   0.99192  |    0.990302 | 0.9802   | 0.985166 |
# +----+----------------+----------+------------+-------------+----------+----------+
# |  2 | KNN+MLP+GB     | soft     |   0.939884 |    0.957586 | 0.822778 | 0.872746 |
# +----+----------------+----------+------------+-------------+----------+----------+
# |  3 | KNN+NB+DT      | soft     |   0.992459 |    0.990641 | 0.981835 | 0.986174 |
# +----+----------------+----------+------------+-------------+----------+----------+
# ...

# %%
Accuracy = [Vt_KNN_MLP_NB_accuracy, Vt_KNN_MLP_DT_accuracy, Vt_KNN_MLP_GB_accuracy, Vt_KNN_NB_DT_accuracy,
                    Vt_KNN_NB_GB_accuracy, Vt_KNN_DT_GB_accuracy, Vt_MLP_NB_DT_accuracy, Vt_MLP_NB_GB_accuracy,
                    Vt_MLP_DT_GB_accuracy,Vt_NB_DT_GB_accuracy]
Precision = [Vt_KNN_MLP_NB_Precision, Vt_KNN_MLP_DT_Precision, Vt_KNN_MLP_GB_Precision, Vt_KNN_NB_DT_Precision,
                    Vt_KNN_NB_GB_Precision, Vt_KNN_DT_GB_Precision, Vt_MLP_NB_DT_Precision, Vt_MLP_NB_GB_Precision,
                    Vt_MLP_DT_GB_Precision,Vt_NB_DT_GB_Precision]
Recall = [Vt_KNN_MLP_NB_Recall, Vt_KNN_MLP_DT_Recall, Vt_KNN_MLP_GB_Recall, Vt_KNN_NB_DT_Recall,
                    Vt_KNN_NB_GB_Recall, Vt_KNN_DT_GB_Recall, Vt_MLP_NB_DT_Recall, Vt_MLP_NB_GB_Recall,
                    Vt_MLP_DT_GB_Recall,Vt_NB_DT_GB_Recall]
F1= [Vt_KNN_MLP_NB_F1, Vt_KNN_MLP_DT_F1, Vt_KNN_MLP_GB_F1, Vt_KNN_NB_DT_F1,
                    Vt_KNN_NB_GB_F1, Vt_KNN_DT_GB_F1, Vt_MLP_NB_DT_F1, Vt_MLP_NB_GB_F1,
                    Vt_MLP_DT_GB_F1,Vt_NB_DT_GB_F1]
index = ['KNN+MLP+NB','KNN+MLP+DT','KNN+MLP+GB','KNN+NB+DT','KNN+NB+GB','KNN+DT+GB',
                      'MLP+NB+DT','MLP+NB+GB','MLP+DT+GB','NB+DT+GB']
                       
df = pd.DataFrame({'Accuracy': Accuracy,
                   'Precision': Precision,
                   'Recall': Recall, 
                   'F1 Score': F1}, index=index)
ax = df.plot.bar(rot=1,figsize=(15, 8))

# %% [markdown]
# # Voting Classifier with Four estimators

# %% [markdown]
# # VC: KNN + MLP + NB + DT

# %%
# create the voting classifier
Vt_KNN_MLP_NB_DT = VotingClassifier(estimators=[('knn', KNN), ('mlp', MLP), ('nb', NB), ('dt', DT)], voting = 'hard')
# train the classifier
Vt_KNN_MLP_NB_DT.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_MLP_NB_DT_pred = Vt_KNN_MLP_NB_DT.predict(x_test)

# metrics evaluation
Vt_KNN_MLP_NB_DT_accuracy = (accuracy_score(y_test, Vt_KNN_MLP_NB_DT_pred))
Vt_KNN_MLP_NB_DT_Precision=precision_score(y_test, Vt_KNN_MLP_NB_DT_pred, average='macro') 
Vt_KNN_MLP_NB_DT_Recall = recall_score(y_test,Vt_KNN_MLP_NB_DT_pred, average='macro')
Vt_KNN_MLP_NB_DT_F1 = f1_score(y_test, Vt_KNN_MLP_NB_DT_pred, average='macro')

print("Accuracy :",Vt_KNN_MLP_NB_DT_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_MLP_NB_DT_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_MLP_NB_DT_Recall, "\n%s" % 
      "F1       :",Vt_KNN_MLP_NB_DT_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_MLP_NB_DT_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_MLP_NB_DT_pred, digits=5))
# Out:
# Accuracy : 0.9779142426201249
# Precision: 0.951933279124596
# Recall   : 0.9699780341996351
# F1       : 0.9606612912178987
#
# Confusion Matrix:
#
# [[1465   64]
#  [ 141 7612]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.91220   0.95814   0.93461      1529
#          1.0    0.99166   0.98181   0.98671      7753
#
#     accuracy                        0.97791      9282
#    macro avg    0.95193   0.96998   0.96066      9282
# weighted avg    0.97857   0.97791   0.97813      9282

# %% [markdown]
# # VC: KNN + MLP + NB + GB

# %%
# create the voting classifier
Vt_KNN_MLP_NB_GB = VotingClassifier(estimators=[('knn', KNN), ('mlp', MLP), ('nb', NB), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_KNN_MLP_NB_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_MLP_NB_GB_pred = Vt_KNN_MLP_NB_GB.predict(x_test)

# metrics evaluation
Vt_KNN_MLP_NB_GB_accuracy = (accuracy_score(y_test, Vt_KNN_MLP_NB_GB_pred))
Vt_KNN_MLP_NB_GB_Precision=precision_score(y_test, Vt_KNN_MLP_NB_GB_pred, average='macro') 
Vt_KNN_MLP_NB_GB_Recall = recall_score(y_test,Vt_KNN_MLP_NB_GB_pred, average='macro')
Vt_KNN_MLP_NB_GB_F1 = f1_score(y_test, Vt_KNN_MLP_NB_GB_pred, average='macro')

print("Accuracy :",Vt_KNN_MLP_NB_GB_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_MLP_NB_GB_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_MLP_NB_GB_Recall, "\n%s" % 
      "F1       :",Vt_KNN_MLP_NB_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_MLP_NB_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_MLP_NB_GB_pred, digits=5))
# Out:
# Accuracy : 0.9126265890971773
# Precision: 0.9300158286127786
# Recall   : 0.7450322611884579
# F1       : 0.8006206484190788
#
# Confusion Matrix:
#
# [[ 757  772]
#  [  39 7714]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.95101   0.49509   0.65118      1529
#          1.0    0.90903   0.99497   0.95006      7753
#
#     accuracy                        0.91263      9282
#    macro avg    0.93002   0.74503   0.80062      9282
# weighted avg    0.91594   0.91263   0.90083      9282

# %% [markdown]
# # VC: KNN + NB + DT + GB

# %%
# create the voting classifier
Vt_KNN_NB_DT_GB = VotingClassifier(estimators=[('knn', KNN), ('nb', NB), ('dt', DT), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_KNN_NB_DT_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_NB_DT_GB_pred = Vt_KNN_NB_DT_GB.predict(x_test)

# metrics evaluation
Vt_KNN_NB_DT_GB_accuracy = (accuracy_score(y_test, Vt_KNN_NB_DT_GB_pred))
Vt_KNN_NB_DT_GB_Precision=precision_score(y_test, Vt_KNN_NB_DT_GB_pred, average='macro') 
Vt_KNN_NB_DT_GB_Recall = recall_score(y_test,Vt_KNN_NB_DT_GB_pred, average='macro')
Vt_KNN_NB_DT_GB_F1 = f1_score(y_test, Vt_KNN_NB_DT_GB_pred, average='macro')

print("Accuracy :",Vt_KNN_NB_DT_GB_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_NB_DT_GB_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_NB_DT_GB_Recall, "\n%s" % 
      "F1       :",Vt_KNN_NB_DT_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_NB_DT_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_NB_DT_GB_pred, digits=5))
# Out:
# Accuracy : 0.9878258995906055
# Precision: 0.9913731172321992
# Recall   : 0.9643603433916211
# F1       : 0.9772601580566724
#
# Confusion Matrix:
#
# [[1421  108]
#  [   5 7748]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.99649   0.92937   0.96176      1529
#          1.0    0.98625   0.99936   0.99276      7753
#
#     accuracy                        0.98783      9282
#    macro avg    0.99137   0.96436   0.97726      9282
# weighted avg    0.98794   0.98783   0.98765      9282

# %% [markdown]
# # VC: KNN + MLP + DT + GB

# %%
# create the voting classifier
Vt_KNN_MLP_DT_GB = VotingClassifier(estimators=[('knn', KNN), ('mlp', MLP), ('dt', DT), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_KNN_MLP_DT_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_MLP_DT_GB_pred = Vt_KNN_MLP_DT_GB.predict(x_test)

# metrics evaluation
Vt_KNN_MLP_DT_GB_accuracy = (accuracy_score(y_test, Vt_KNN_MLP_DT_GB_pred))
Vt_KNN_MLP_DT_GB_Precision=precision_score(y_test, Vt_KNN_MLP_DT_GB_pred, average='macro') 
Vt_KNN_MLP_DT_GB_Recall = recall_score(y_test,Vt_KNN_MLP_DT_GB_pred, average='macro')
Vt_KNN_MLP_DT_GB_F1 = f1_score(y_test, Vt_KNN_MLP_DT_GB_pred, average='macro')

print("Accuracy :",Vt_KNN_MLP_DT_GB_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_MLP_DT_GB_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_MLP_DT_GB_Recall, "\n%s" % 
      "F1       :",Vt_KNN_MLP_DT_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_MLP_DT_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_MLP_DT_GB_pred, digits=5))
# Out:
# Accuracy : 0.9878258995906055
# Precision: 0.9916598985932894
# Recall   : 0.9640978234379536
# F1       : 0.9772476721601071
#
# Confusion Matrix:
#
# [[1420  109]
#  [   4 7749]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.99719   0.92871   0.96173      1529
#          1.0    0.98613   0.99948   0.99276      7753
#
#     accuracy                        0.98783      9282
#    macro avg    0.99166   0.96410   0.97725      9282
# weighted avg    0.98795   0.98783   0.98765      9282

# %% [markdown]
# # VC: MLP + NB + DT + GB

# %%
# create the voting classifier
Vt_MLP_NB_DT_GB = VotingClassifier(estimators=[('mlp', MLP), ('nb', NB), ('dt', DT), ('gb', GB)], voting = 'soft')
# train the classifier
Vt_MLP_NB_DT_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_MLP_NB_DT_GB_pred = Vt_MLP_NB_DT_GB.predict(x_test)

# metrics evaluation
Vt_MLP_NB_DT_GB_accuracy = (accuracy_score(y_test, Vt_MLP_NB_DT_GB_pred))
Vt_MLP_NB_DT_GB_Precision=precision_score(y_test, Vt_MLP_NB_DT_GB_pred, average='macro') 
Vt_MLP_NB_DT_GB_Recall = recall_score(y_test,Vt_MLP_NB_DT_GB_pred, average='macro')
Vt_MLP_NB_DT_GB_F1 = f1_score(y_test, Vt_MLP_NB_DT_GB_pred, average='macro')

print("Accuracy :",Vt_MLP_NB_DT_GB_accuracy,"\n%s" % 
      "Precision:",Vt_MLP_NB_DT_GB_Precision,"\n%s" % 
      "Recall   :",Vt_MLP_NB_DT_GB_Recall, "\n%s" % 
      "F1       :",Vt_MLP_NB_DT_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_MLP_NB_DT_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_MLP_NB_DT_GB_pred, digits=5))
# Out:
# Accuracy : 0.9151045033397974
# Precision: 0.935011130484368
# Recall   : 0.7509783971891468
# F1       : 0.8070565925290636
#
# Confusion Matrix:
#
# [[ 774  755]
#  [  33 7720]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.95911   0.50621   0.66267      1529
#          1.0    0.91091   0.99574   0.95144      7753
#
#     accuracy                        0.91510      9282
#    macro avg    0.93501   0.75098   0.80706      9282
# weighted avg    0.91885   0.91510   0.90387      9282

# %% [markdown]
# # VC: KNN + MLP + NB + DT + GB

# %%
# create the voting classifier
Vt_KNN_MLP_NB_DT_GB = VotingClassifier(estimators=[('knn', KNN), ('mlp', MLP), ('nb', NB), ('dt', DT),('gb', GB)], voting = 'soft')
# train the classifier
Vt_KNN_MLP_NB_DT_GB.fit(x_train, y_train.ravel())
# predict the test samples
Vt_KNN_MLP_NB_DT_GB_pred = Vt_KNN_MLP_NB_DT_GB.predict(x_test)

# metrics evaluation
Vt_KNN_MLP_NB_DT_GB_accuracy = (accuracy_score(y_test, Vt_KNN_MLP_NB_DT_GB_pred))
Vt_KNN_MLP_NB_DT_GB_Precision=precision_score(y_test, Vt_KNN_MLP_NB_DT_GB_pred, average='macro') 
Vt_KNN_MLP_NB_DT_GB_Recall = recall_score(y_test,Vt_KNN_MLP_NB_DT_GB_pred, average='macro')
Vt_KNN_MLP_NB_DT_GB_F1 = f1_score(y_test, Vt_KNN_MLP_NB_DT_GB_pred, average='macro')

print("Accuracy :",Vt_KNN_MLP_NB_DT_GB_accuracy,"\n%s" % 
      "Precision:",Vt_KNN_MLP_NB_DT_GB_Precision,"\n%s" % 
      "Recall   :",Vt_KNN_MLP_NB_DT_GB_Recall, "\n%s" % 
      "F1       :",Vt_KNN_MLP_NB_DT_GB_F1, "\n")

print("Confusion Matrix:\n\n%s\n" % (confusion_matrix(y_test, Vt_KNN_MLP_NB_DT_GB_pred)))
print("Classification Report:\n\n%s\n" % classification_report(y_test,Vt_KNN_MLP_NB_DT_GB_pred, digits=5))
# Out:
# Accuracy : 0.962508080155139
# Precision: 0.9763455115900983
# Recall   : 0.8877752505264529
# F1       : 0.9250929527170448
#
# Confusion Matrix:
#
# [[1187  342]
#  [   6 7747]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0    0.99497   0.77632   0.87215      1529
#          1.0    0.95772   0.99923   0.97803      7753
#
#     accuracy                        0.96251      9282
#    macro avg    0.97635   0.88778   0.92509      9282
# weighted avg    0.96386   0.96251   0.96059      9282

# %% [markdown]
# # Metrics - VC: Four & Five Estimators

# %%
# creating a DataFrame
dict = {'Estimators':['KNN+MLP+NB+DT','KNN+MLP+NB+GB','KNN+NB+DT+GB','KNN+MLP+DT+GB', 'MLP+NB+DT+GB',
                      'KNN+MLP+NB+DT+GB'],
                                       
        'Config': ['hard','soft','soft','soft','soft','soft'],
        'Accuracy':[Vt_KNN_MLP_NB_DT_accuracy,Vt_KNN_MLP_NB_GB_accuracy,Vt_KNN_NB_DT_GB_accuracy,
                    Vt_KNN_MLP_DT_GB_accuracy, Vt_MLP_NB_DT_GB_accuracy,Vt_KNN_MLP_NB_DT_GB_accuracy],
                   
                                       
        'Precision':[Vt_KNN_MLP_NB_DT_Precision,Vt_KNN_MLP_NB_GB_Precision,Vt_KNN_NB_DT_GB_Precision,
                    Vt_KNN_MLP_DT_GB_Precision, Vt_MLP_NB_DT_GB_Precision,Vt_KNN_MLP_NB_DT_GB_Precision],
        
        'Recall':[Vt_KNN_MLP_NB_DT_Recall,Vt_KNN_MLP_NB_GB_Recall,Vt_KNN_NB_DT_GB_Recall,
                    Vt_KNN_MLP_DT_GB_Recall, Vt_MLP_NB_DT_GB_Recall,Vt_KNN_MLP_NB_DT_GB_Recall],
        
        'F1': [Vt_KNN_MLP_NB_DT_F1,Vt_KNN_MLP_NB_GB_F1,Vt_KNN_NB_DT_GB_F1,
                    Vt_KNN_MLP_DT_GB_F1, Vt_MLP_NB_DT_GB_F1, Vt_KNN_MLP_NB_DT_GB_F1]
       }
df = pd.DataFrame(dict)
  
# displaying the DataFrame
# print(tabulate(df, headers = 'keys', tablefmt = 'psql'))

head = ["3 Estimators", "Config", "Accuracy", "Precision", "Recall", "F1"]

print(tabulate(df, headers=head, tablefmt="grid"))
# Out:
# +----+------------------+----------+------------+-------------+----------+----------+
# |    | 3 Estimators     | Config   |   Accuracy |   Precision |   Recall |       F1 |
# +====+==================+==========+============+=============+==========+==========+
# |  0 | KNN+MLP+NB+DT    | hard     |   0.977914 |    0.951933 | 0.969978 | 0.960661 |
# +----+------------------+----------+------------+-------------+----------+----------+
# |  1 | KNN+MLP+NB+GB    | soft     |   0.912627 |    0.930016 | 0.745032 | 0.800621 |
# +----+------------------+----------+------------+-------------+----------+----------+
# |  2 | KNN+NB+DT+GB     | soft     |   0.987826 |    0.991373 | 0.96436  | 0.97726  |
# +----+------------------+----------+------------+-------------+----------+----------+
# |  3 | KNN+MLP+DT+GB    | soft     |   0.987826 |    0.99166  | 0.964098 | 0.977248 |
# +----+------------------+----------+------------+-------------+----------+----------+
# ...

# %%
Accuracy = [Vt_KNN_MLP_NB_DT_accuracy,Vt_KNN_MLP_NB_GB_accuracy,Vt_KNN_NB_DT_GB_accuracy,
                    Vt_KNN_MLP_DT_GB_accuracy, Vt_MLP_NB_DT_GB_accuracy, Vt_KNN_MLP_NB_DT_GB_accuracy]
Precision = [Vt_KNN_MLP_NB_DT_Precision,Vt_KNN_MLP_NB_GB_Precision,Vt_KNN_NB_DT_GB_Precision,
                    Vt_KNN_MLP_DT_GB_Precision, Vt_MLP_NB_DT_GB_Precision, Vt_KNN_MLP_NB_DT_GB_Precision]
Recall = [Vt_KNN_MLP_NB_DT_Recall,Vt_KNN_MLP_NB_GB_Recall,Vt_KNN_NB_DT_GB_Recall,
                    Vt_KNN_MLP_DT_GB_Recall, Vt_MLP_NB_DT_GB_Recall,Vt_KNN_MLP_NB_DT_GB_Recall]
F1= [Vt_KNN_MLP_NB_DT_F1,Vt_KNN_MLP_NB_GB_F1,Vt_KNN_NB_DT_GB_F1,
                    Vt_KNN_MLP_DT_GB_F1, Vt_MLP_NB_DT_GB_F1, Vt_KNN_MLP_NB_DT_GB_F1]
index = ['KNN+MLP+NB+DT','KNN+MLP+NB+GB','KNN+NB+DT+GB','KNN+MLP+DT+GB', 'MLP+NB+DT+GB', 'KNN+MLP+NB+DT+GB']
                       
df = pd.DataFrame({'Accuracy': Accuracy,
                   'Precision': Precision,
                   'Recall': Recall, 
                   'F1 Score': F1}, index=index)
ax = df.plot.bar(rot=1,figsize=(14, 8))
